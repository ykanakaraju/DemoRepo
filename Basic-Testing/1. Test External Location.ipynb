# %%
# %fs ls abfss://demo@ucdemodataykrsa.dfs.core.windows.net/

# %%
circuits_path = "abfss://demo@ucdemodataykrsa.dfs.core.windows.net/circuits.csv"

df = spark.read.csv(circuits_path, header=True, inferSchema=True)
display(df)

# %%
df.where("country = 'Spain'").display()

# %%
df.where("country = 'Spain'").coalesce(1) \
    .write \
    .format("csv") \
    .save("abfss://demo@ucdemodataykrsa.dfs.core.windows.net/circuits-spain")

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `bookstore-landing`
URL "abfss://bookstore-landing@ucdemodataykrsa.dfs.core.windows.net/"
WITH (STORAGE CREDENTIAL `ucdemodataykrsa-cred`);

# %%
# %sql
SHOW EXTERNAL LOCATIONS

# %%
# %fs ls dbfs:/FileStore/bookstore/books-streaming

# %%
# %sql
SELECT * FROM JSON.`dbfs:/FileStore/bookstore/books-streaming/01.json`

# %%
# %sql
SELECT * FROM JSON.`dbfs:/FileStore/bookstore/books-streaming/02.json`

# %%
# %sql
SELECT * FROM JSON.`dbfs:/FileStore/bookstore/books-streaming/03.json`
